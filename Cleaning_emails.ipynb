# %%
import pandas as pd
#read an RTF file
with open('EPA_Emails.rtf', 'r') as file:
    text = file.read()
print(text)
# Out:
# {\rtf1\ansi\ansicpg1252\cocoartf2580
# \cocoatextscaling0\cocoaplatform0{\fonttbl\f0\fswiss\fcharset0 ArialMT;\f1\froman\fcharset0 TimesNewRomanPSMT;\f2\fswiss\fcharset0 Helvetica;
# }
# {\colortbl;\red255\green255\blue255;\red34\green34\blue34;\red17\green85\blue204;}
# {\*\expandedcolortbl;;\csgenericrgb\c13333\c13333\c13333;\csgenericrgb\c6667\c33333\c80000;}
# \margl1440\margr1440\vieww11520\viewh8400\viewkind0
# \deftab720
# \pard\pardeftab720\ri0\partightenfactor0
#
# ...

# %%
#I'm able to extract the emails just fine but I want to get the names too

# %%
#Extracts the emails 
emails = re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", text)
print (emails)
# Out:
# ['oug@epa.gov', 'jason@krwa.net', 'jason@krwa.net', 'mendrala.angela@epa.gov', 'zdorsey@watereuse.org', 'zdorsey@watereuse.org', 'mily@epa.gov', 'magdangal.david@epa.gov', 'john.hoke@dnr.mo.gov', 'john.hoke@dnr.mo.gov', 'mike@civildynamics.net', 'mike@civildynamics.net', 'bmartin@cdaid.org', 'bmartin@cdaid.org', 'kevin.calcagno@eurofinset.com', 'kevin.calcagno@eurofinset.com', 'dupree.gabriel@epa.gov', 'ichie@epa.gov', 'bwithrow@kunaid.gov', 'bwithrow@kunaid.gov', 'oe@epa.gov', 'mmcdonald@m-m.net', 'mmcdonald@m-m.net', 'ric@envirospectives.com', 'ric@envirospectives.com', 'kdl@xegy.com', 'kdl@xegy.com', 'cbrennan@coastsidewater.org', 'cbrennan@coastsidewater.org', 'brad.bjerke@hdrinc.com', 'brad.bjerke@hdrinc.com', 'dlennon@trcsolutions.com', 'dlennon@trcsolutions.com', 'kbourque@goletawater.com', 'kbourque@goletawater.com', 'jennifer.acton@flysfo.com', 'jennifer.acton@flysfo.com', 'melanie.greene@cardno.com', 'melanie.greene@cardno.com', 'sydneyc@trusselltech.com', 'sydneyc@trussell
# ...

# %%
#Remove duplicates
mylist = emails
mylist = list(dict.fromkeys(mylist))
print(mylist)
# Out:
# ['oug@epa.gov', 'jason@krwa.net', 'mendrala.angela@epa.gov', 'zdorsey@watereuse.org', 'mily@epa.gov', 'magdangal.david@epa.gov', 'john.hoke@dnr.mo.gov', 'mike@civildynamics.net', 'bmartin@cdaid.org', 'kevin.calcagno@eurofinset.com', 'dupree.gabriel@epa.gov', 'ichie@epa.gov', 'bwithrow@kunaid.gov', 'oe@epa.gov', 'mmcdonald@m-m.net', 'ric@envirospectives.com', 'kdl@xegy.com', 'cbrennan@coastsidewater.org', 'brad.bjerke@hdrinc.com', 'dlennon@trcsolutions.com', 'kbourque@goletawater.com', 'jennifer.acton@flysfo.com', 'melanie.greene@cardno.com', 'sydneyc@trusselltech.com', 'lmiracle@cityofredlands.org', 'bcastorina@tucor.com', 'adykman@piedmont.ca.gov', 'rebeca.griner@waterboards.ca.gov', 'tricia.lee@waterboards.ca.gov', 'jjackson@banningca.gov', 'aprebble@sterling-kansas.com', 'saed@birzeit.edu', 'srogers@palmdalewater.org', 'athebo@pacinst.org', 'stacey@ampac1.com', 'damchak@usda.gov', 'cornejop@emwd.org', 'alderperson2@cityofsanelizario.com', 'jim.kang@waterboards.ca.gov', 'jenniferla
# ...

# %%
#Turn into CSV
df = pd.DataFrame(mylist)
df.to_csv('epa_emails.csv',index=False)
